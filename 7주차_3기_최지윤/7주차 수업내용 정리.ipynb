# %% [markdown]
# # **CV (Computer Vision)**
# 공간 개념이 없는 분류와 객체 검출 기술 개요
#
#
# ---
#
# # **Object Detection (객체 검출)**
#
# **R-CNN:**
# - 각 독립적 ConvNet 통과.
#
#
# ---
#
#
# **fast R-CNN**
# - 한 번의 ConvNet으로 Feature Map 생성 후 RoI Pooling 적용, 빠른 연산.
#
# **RoI Pooling**
# - 관심 영역을 그리드로 나눈 뒤 Max Pooling 적용.
# 주요 도구 및 리소스 링크 제공:
#
#
# ---
#
#
# **YOLO**
# - One-Stage,Two Stage 방식, 이미지 전체를 ConvNet으로 처리, Rol 빠져서 빠른 속도. 작은 물체는 R-CNN 계열이 유리.
#
#
#
# ---
#
# # **Image Segmentation (이미지 분할)**
# **Semantic Segmentation**
# - 단순 픽셀 변화에 따른 것
#
# **Instance Segmentation**
#
#
# **Mask R-CNN**
#
#
#
# **Pose Estimation (포즈 추정)**
# - 관절 위치를 픽셀 단위로 탐지 후 회귀 네트워크로 정확도 보정.
#
# ---
#
# **대표적 pose estimation 오픈소스 라이브러리:**
# 1. OpenPose
# 2. MediaPipe
# 3. DensePose
#
#
# ---
#
# **CNN 계층 이해**
# - 연산량 비교:
# - 1x1 필터 vs 3x3 필터 vs. 5x5 필터
# - 1x1 필터 사용 시 연산량 감소
#
# **Vision Transformer (ViT)**
# - 이미지를 작은 조각으로 나눈 후 선형 변환 및 Transformer Encoder를 통해 최종 클래스 예측.
