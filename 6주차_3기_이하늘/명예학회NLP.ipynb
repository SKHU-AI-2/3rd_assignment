# %% [markdown]
# ### Package Install

# %%
# !pip install langchain_groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain transformers torch faiss-cpu pypdf sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 45.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 24.1 MB/s eta 0:00:00
# ...

# %%
# !pip install tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.2 MB/s eta 0:00:00
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 78.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 100.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.6/166.6 kB 17.8 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.21
#     Uninstalling langchain-core-0.3.21:
#       Successfully uninstalled langchain-core-0.3.21
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.9
#     Uninstalling langchain-0.3.9:
#       Successfully uninstalled langchain-0.3.9
# ...

# %%
pip install pypdf

# %% [markdown]
# ## 실행 데모

# %%
api_key =

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

# ChatGroq 모델 초기화
llm = ChatGroq(
    model="gemma2-9b-it",
    temperature=0.7,
    max_tokens=500,
    api_key=api_key
)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """당신은 위인의 MBTI를 추측해주는 챗봇입니다.
MBTI는 심리학자 Carl Jung의 심리 유형 이론을 기반으로 한 성격 유형 검사로, 다음의 네 가지 차원에 따라 16가지 성격 유형으로 나뉩니다:

1. **외향(E) vs. 내향(I)**:
   - 외향형은 외부 세계와의 상호작용에서 에너지를 얻고, 내향형은 자신의 내면에서 에너지를 얻습니다.

2. **감각(S) vs. 직관(N)**:
   - 감각형은 구체적이고 현재 중심적인 정보를 선호하며, 직관형은 가능성과 큰 그림을 선호합니다.

3. **사고(T) vs. 감정(F)**:
   - 사고형은 논리와 객관적인 판단을, 감정형은 사람과 감정을 중심으로 판단합니다.

4. **판단(J) vs. 인식(P)**:
   - 판단형은 체계적이고 계획적인 것을 선호하며, 인식형은 유연하고 즉흥적인 것을 선호합니다.

당신은 위인의 MBTI를 추측하기 위해 위인의 행동, 업적, 성격 등을 기반으로 분석을 제공합니다. 위인의 이름을 입력하면, 가능한 MBTI 유형을 추측합니다

예) "잔다르크: INFP" "레오나르도 다빈치: INTP" 등.
."""),
    ("human", "{question}")
])

chain = prompt | llm

# 질문 리스트
questions = [
    "스티브잡스",
    "이순신",
    "나폴레옹"
]

# 각 질문에 대한 답변 생성
for question in questions:
    response = chain.invoke({"question": question})
    print(f"질문: {question}")
    print(f"답변: {response.content}\n")
    print("="*100)
# Out:
# 질문: 스티브잡스
# 답변: 스티브 잡스의 MBTI 유형은 **INTJ**로 추측됩니다.
#
# 다음과 같은 이유로 이러한 추측을 뒷받침하는 자료들이 있습니다.
#
# * **내향(I):** 스티브 잡스는 극도로 집중력을 가지고 있으며, 자신의 생각과 아이디어를 개발하는 데 많은 시간을 보냈습니다. 그는 대중적인 주목을 피하는 경향이 있었고, 외부 자극보다는 내면 세계에서 에너지를 얻는 것으로 보입니다.
# * **직관(N):**
# 잡스는 미래를 예측하고 혁신적인 아이디어를 끊임없이 제시했습니다. 그는 현실적인 문제 해결뿐만 아니라 잠재적 가능성과 큰 그림을 탐구하는 데 뛰어났습니다.
# * **사고(T):**
# 잡스는 논리적 사고와 분석적인 접근방식을 선호했습니다. 그의 제품 개발 과정과 사업 전략은 객관적인 데이터와 분석을 바탕으로 이루어졌습니다.
# * **판단(J):** 잡스는 명확한 비전과 계획을 가지고 있었으며, 이를 실행하기 위해 체계적이고 효율적인 방식으로 작업했습니다. 그는 사전에 준비하고 계획을 세우는 것을 중요하게 여겼습니다.
#
# 물론, 이는 추측일 뿐이며 스티브 잡스 본인이 MBTI 검사를 받았는지 확인된 정보는 없습니다. 하지만 그의 행동, 업적, 성격 특징들을 종합해 볼 때 INTJ 유형이 가장 타당해 보입니다.
#
#
#
#
# ...
# 질문: 이순신
# 답변: 이순신: **ESTJ**
#
# **근거:**
#
# * **외향**: 이순신은 끊임없이 활동적이고, 군대를 이끄는 리더로서 주도적인 역할을 수행했습니다.
# * **감각**: 그는 전쟁 현장에서 현실적인 상황을 파악하고, 구체적인 전략을 세우는 데 능숙했습니다.
# * **사고**: 이순신은 논리적 사고와 전략적 사고로 유명했습니다.  감정에 흔들리지 않고, 객관적인 판단을 통해 승리를 이끌어냈습니다.
# * **판단**: 그는 체계적인 계획과 실행 능력을 통해 군사적으로 성공을 거두었습니다.  꼼꼼하게 준비하고 계획적인 방식으로 전투를 이끌었습니다.
#
#
#
# ...

# %%
pip install langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.9/389.9 kB 30.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.54.5
#     Uninstalling openai-1.54.5:
#       Successfully uninstalled openai-1.54.5
# ...

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser

import os
import tempfile

# OpenAI API 키 설정
os.environ["OPENAI_API_KEY"] =
# PDF 처리 함수
def process_pdf(pdf_file):
    with tempfile.NamedTemporaryFile(delete=False, suffix=".pdf") as temp_file:
        temp_file.write(pdf_file.read())
        temp_file_path = temp_file.name

    loader = PyPDFLoader(temp_file_path)
    documents = loader.load()
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    texts = text_splitter.split_documents(documents)

    os.unlink(temp_file_path)

    return texts

# 벡터 저장소 생성
def create_vectorstore(texts):
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_documents(texts, embeddings)
    return vectorstore

# 검색된 문서들을 하나의 문자열로 반환
def format_docs(docs):
    return '\n\n'.join(doc.page_content for doc in docs)

# RAG 체인 설정
def setup_rag_chain(vectorstore):
    template = '''You are a helpful AI assistant. You are a financial expert helping small businesses make informed decisions.
    Answer the question based only on following context:
    {context}

    Question: {question}
    '''

    prompt = ChatPromptTemplate.from_template(template)

    retriever = vectorstore.as_retriever()
    llm = ChatGroq(
    model="gemma2-9b-it",
    temperature=0.7,
    max_tokens=300,
    api_key=api_key
    )
    rag_chain = (
        {'context': retriever | format_docs, 'question': RunnablePassthrough()}
        | prompt
        | llm
        | StrOutputParser()
    )

    return rag_chain

# 메인 함수
def main():
    # 파일 업로드 시뮬레이션
    pdf_file = open(input("업로드할 PDF 파일 경로를 입력하세요: "), "rb")

    texts = process_pdf(pdf_file)
    vectorstore = create_vectorstore(texts)
    rag_chain = setup_rag_chain(vectorstore)

    while True:
        query = input("질문을 입력하세요 (종료하려면 'exit' 입력): ")
        if query.lower() == 'exit':
            break
        result = rag_chain.invoke(query)
        print("답변:", result)

if __name__ == "__main__":
    main()
# Out:
# 업로드할 PDF 파일 경로를 입력하세요: /content/호텔 예매 데이터.pdf
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-21-27c0e4b0d961> in <cell line: 84>()
#      83
#      84 if __name__ == "__main__":
# ---> 85     main()
#
# <ipython-input-21-27c0e4b0d961> in main()
#      72
#      73     texts = process_pdf(pdf_file)
# ---> 74     vectorstore = create_vectorstore(texts)
#      75     rag_chain = setup_rag_chain(vectorstore)
#      76
#
# <ipython-input-21-27c0e4b0d961> in create_vectorstore(texts)
#      32 def create_vectorstore(texts):
#      33     embeddings = OpenAIEmbeddings()
# ---> 34     vectorstore = FAISS.from_documents(texts, embeddings)
#      35     return vectorstore
#      36
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     850                 kwargs["ids"] = ids
#     851
# ...
